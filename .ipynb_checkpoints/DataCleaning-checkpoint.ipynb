# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import re
import seaborn as sns

# %%
mov_train=pd.read_csv("./DataSets/mov_train.csv")
mov_train.head()
# Out:
#    Unnamed: 0  id                              belongs_to_collection  \
# 0           0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1           1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2           2   3                                                NaN
# 3           3   4                                                NaN
# 4           4   5                                                NaN
#
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  ...  \
# 0  When Lou, who has become the "father of the In...  ...
# 1  Mia Thermopolis is now a college graduate and ...  ...
# 2  Under the direction of a ruthless instructor, ...  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...  ...
# 4  Marine Boy is the story of a former national s...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes
# 0   39572.0
# 1   82272.0
# 2  852772.0
# 3   63220.0
# 4     316.0
#
# [5 rows x 26 columns]

# %%
actors=pd.read_csv("./DataSets/actors.csv")
actors.head()
# Out:
#          Unnamed: 0  MoviesN    AvgPop   AvgIMDB     Score
# 0          Stan Lee        8  0.257924  0.762346  0.606930
# 1      Gino Corrado        6  0.027834  0.849794  0.574599
# 2   Joseph Oliveira        5  0.163211  0.861728  0.574432
# 3       Andy Serkis       10  0.117575  0.766667  0.571418
# 4  Philip Ettington       15  0.053379  0.772840  0.556998

# %%
mov_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3000 non-null   int64
#  1   id                     3000 non-null   int64
#  2   belongs_to_collection  604 non-null    object
#  3   budget                 3000 non-null   int64
#  4   genres                 2993 non-null   object
#  5   homepage               946 non-null    object
#  6   imdb_id                3000 non-null   object
#  7   original_language      3000 non-null   object
#  8   original_title         3000 non-null   object
#  9   overview               2992 non-null   object
#  10  popularity             3000 non-null   float64
#  11  poster_path            2999 non-null   object
#  12  production_companies   2844 non-null   object
#  13  production_countries   2945 non-null   object
#  14  release_date           3000 non-null   object
#  15  runtime                2998 non-null   float64
#  16  spoken_languages       2980 non-null   object
#  17  status                 3000 non-null   object
#  18  tagline                2403 non-null   object
#  19  title                  3000 non-null   object
#  20  Keywords               2724 non-null   object
#  21  cast                   2987 non-null   object
#  22  crew                   2984 non-null   object
#  23  revenue                3000 non-null   int64
#  24  imdb_rating            2998 non-null   float64
#  25  numVotes               2998 non-null   float64
# dtypes: float64(4), int64(4), object(18)
# memory usage: 609.5+ KB

# %%
mov_train['Keywords']
# Out:
# 0       [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1       [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2       [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3       [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                     NaN
#                               ...
# 2995    [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996    [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997    [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998    [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999    [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# Name: Keywords, Length: 3000, dtype: object

# %%
mov_train.drop(columns = ['id', 'Unnamed: 0','belongs_to_collection','homepage','overview','poster_path','tagline'],inplace=True)

# %%
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue  imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651          5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435          5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000          8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000          8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970          5.7
#
#    numVotes
# 0   39572.0
# 1   82272.0
# 2  852772.0
# 3   63220.0
# 4     316.0

# %%
mov_train[mov_train['status']!='Released']
# Out:
#       budget                                             genres    imdb_id  \
# 609        0  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...  tt0120254
# 1007       0                     [{'id': 35, 'name': 'Comedy'}]  tt1860180
# 1216       0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...  tt0091024
# 1618  891000                [{'id': 99, 'name': 'Documentary'}]  tt0145394
#
#      original_language                                  original_title  \
# 609                 en  The Swan Princess: Escape from Castle Mountain
# 1007                en                         Billy Gardell: Halftime
# 1216                en                                     Extremities
# 1618                en                          A Place Called Chiapas
#
#       popularity                               production_companies  \
# 609     5.121309                                                NaN
# 1007    0.007877                                                NaN
# 1216   10.273979  [{'name': 'Atlantic Entertainment Group', 'id'...
# 1618    0.179246                                                NaN
#
#                                    production_countries release_date  runtime  \
# 609                                                 NaN       1/1/97     71.0
# 1007  [{'iso_3166_1': 'US', 'name': 'United States o...       2/5/11     60.0
# 1216  [{'iso_3166_1': 'US', 'name': 'United States o...      8/22/86     89.0
# 1618           [{'iso_3166_1': 'CA', 'name': 'Canada'}]      2/20/98     89.0
#
#                                        spoken_languages   status  \
# 609   [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...  Rumored
# 1007           [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 1216           [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 1618  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Rumored
#
#                                                title  \
# 609   The Swan Princess: Escape from Castle Mountain
# 1007                         Billy Gardell: Halftime
# 1216                                     Extremities
# 1618                          A Place Called Chiapas
#
#                                                Keywords  \
# 609   [{'id': 3071, 'name': 'prince'}, {'id': 4456, ...
# 1007                                                NaN
# 1216  [{'id': 2483, 'name': 'nudity'}, {'id': 2539, ...
# 1618         [{'id': 187056, 'name': 'woman director'}]
#
#                                                    cast  \
# 609   [{'cast_id': 2, 'character': 'Odette (voice)',...
# 1007  [{'cast_id': 9, 'character': 'Himself', 'credi...
# 1216  [{'cast_id': 1, 'character': 'Marjorie', 'cred...
# 1618  [{'cast_id': 1, 'character': 'Himself', 'credi...
#
#                                                    crew   revenue  \
# 609   [{'credit_id': '52fe488bc3a36847f816cfd3', 'de...    273644
# 1007  [{'credit_id': '52fe4be1c3a368484e19d265', 'de...        60
# 1216  [{'credit_id': '582cca1c925141780b00259f', 'de...  13418091
# 1618  [{'credit_id': '57b4f7619251417287000dfc', 'de...    229000
#
#       imdb_rating  numVotes
# 609           5.6    3744.0
# 1007          7.6     111.0
# 1216          6.3    3982.0
# 1618          7.4     392.0

# %%
mov_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                3000 non-null   int64
#  1   genres                2993 non-null   object
#  2   imdb_id               3000 non-null   object
#  3   original_language     3000 non-null   object
#  4   original_title        3000 non-null   object
#  5   popularity            3000 non-null   float64
#  6   production_companies  2844 non-null   object
#  7   production_countries  2945 non-null   object
#  8   release_date          3000 non-null   object
#  9   runtime               2998 non-null   float64
#  10  spoken_languages      2980 non-null   object
#  11  status                3000 non-null   object
#  12  title                 3000 non-null   object
#  13  Keywords              2724 non-null   object
#  14  cast                  2987 non-null   object
#  15  crew                  2984 non-null   object
#  16  revenue               3000 non-null   int64
#  17  imdb_rating           2998 non-null   float64
#  18  numVotes              2998 non-null   float64
# dtypes: float64(4), int64(2), object(13)
# memory usage: 445.4+ KB

# %%
budget_zero = mov_train[mov_train['budget']==0]

# %%
budget_zero.head()
# Out:
#     budget                                             genres    imdb_id  \
# 4        0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# 7        0                [{'id': 99, 'name': 'Documentary'}]  tt0391024
# 8        0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...  tt0117110
# 11       0                     [{'id': 35, 'name': 'Comedy'}]  tt0093857
# 17       0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...  tt1700845
#
#    original_language                              original_title  popularity  \
# 4                 ko                                        마린보이    1.148070
# 7                 en                                Control Room    1.949044
# 8                 en                      Muppet Treasure Island    6.902423
# 11                en  Revenge of the Nerds II: Nerds in Paradise   10.543750
# 17                en                         The Invisible Woman    4.183558
#
#                                  production_companies  \
# 4                                                 NaN
# 7                                                 NaN
# 8   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 11  [{'name': 'Twentieth Century Fox Film Corporat...
# 17  [{'name': 'BBC Films', 'id': 288}, {'name': 'H...
#
#                                  production_countries release_date  runtime  \
# 4       [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
# 7                                                 NaN      1/15/04     84.0
# 8   [{'iso_3166_1': 'US', 'name': 'United States o...      2/16/96    100.0
# 11  [{'iso_3166_1': 'US', 'name': 'United States o...      7/10/87     98.0
# 17   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     12/25/13    111.0
#
#     ...                                               cast  \
# 4   ...  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 7   ...  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8   ...  [{'cast_id': 1, 'character': 'Long John Silver...
# 11  ...  [{'cast_id': 2, 'character': 'Lewis Skolnick',...
# 17  ...  [{'cast_id': 7, 'character': 'Charles Dickens'...
#
#                                                  crew   revenue imdb_rating  \
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
# 7   [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511         7.7
# 8   [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391         6.9
# 11  [{'credit_id': '52fe46f49251416c750891e9', 'de...  22642033         5.0
# 17  [{'credit_id': '53b94a260e0a2676c7009b37', 'de...   1234254         6.1
#
#    numVotes month  year  infl_budget  infl_revenue  mod_budget
# 4     316.0     2  2009          0.0  5.451153e+06         0.0
# 7    5175.0     1  2004          0.0  4.080454e+06         0.0
# 8   24612.0     2  1996          0.0  6.519999e+07         0.0
# 11  14602.0     7  1987          0.0  5.941859e+07         0.0
# 17  10048.0    12  2013          0.0  1.579204e+06         0.0
#
# [5 rows x 24 columns]

# %%
genres=set()
for item in budget_zero.genres:
    print(type(item) == str)
    if isinstance(item,str):
        x=re.finditer("(\'name\':\s\')(?P<name>\w*)(?=\')",item)
        for s in x:
            genres.add(s.groupdict()['name'])
print(genres)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# {'Adventure', 'Western', 'Foreign', 'Thriller', 'Documentary', 'Animation', 'Horror', 'Action', 'Family', 'Fantasy', 'Comedy', 'Mystery', 'Drama', 'History', 'War', 'Romance', 'Music', 'Crime'}

# %%
type(mov_train['release_date'].iloc[5])
# Out:
# str

# %%
mov_train['month']=0

# %%
mov_train['year']=0

# %%
for j in mov_train.index:
    string=mov_train['release_date'].iloc[j]
    x=re.findall("([\d]{1,2})/([\d]{1,2})/([\d]{1,2})",string)
    mov_train.loc[j,"month"] = int(x[0][0])
    year = int(x[0][2])
    if year<23:
        mov_train.loc[j,"year"] = 2000 + year
    else:
        mov_train.loc[j,"year"] = 1900+ year

# %%
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#    ...                                               cast  \
# 0  ...  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  ...  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  ...  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  ...  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  ...  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes month  year   infl_budget  infl_revenue    mod_budget
# 0   39572.0     2  2015  1.760170e+07  1.548277e+07  1.760170e+07
# 1   82272.0     8  2004  6.310360e+07  1.501068e+08  6.310360e+07
# 2  852772.0    10  2014  4.154862e+06  1.648347e+07  4.154862e+06
# 3   63220.0     3  2012  1.557849e+06  2.077131e+07  1.557849e+06
# 4     316.0     2  2009  0.000000e+00  5.451153e+06  0.000000e+00
#
# [5 rows x 24 columns]

# %%
mov_train['year'].min()
# Out:
# 1924

# %%
inflation=pd.read_csv(".\DataSets\inflation_data.csv")

# %%
inflation.loc[0,'amount']
# Out:
# 1.0

# %%
inflation.head()
# Out:
#    year  amount  inflation rate
# 0  1900    1.00            0.01
# 1  1901    1.01            0.01
# 2  1902    1.02            0.01
# 3  1903    1.05            0.02
# 4  1904    1.06            0.01

# %%
revenue_zero = mov_train[mov_train['revenue']==0]
print(revenue_zero)
# Out:
# Empty DataFrame
# Columns: [budget, genres, imdb_id, original_language, original_title, popularity, production_companies, production_countries, release_date, runtime, spoken_languages, status, title, Keywords, cast, crew, revenue, imdb_rating, numVotes, month, year]
# Index: []
#
# [0 rows x 21 columns]

# %%
mov_train['infl_budget']=0
mov_train['infl_revenue']=0

# %%
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#    ...                                           Keywords  \
# 0  ...  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  ...  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  ...  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  ...  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4  ...                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes  month  year  infl_budget  infl_revenue
# 0   39572.0      2  2015            0             0
# 1   82272.0      8  2004            0             0
# 2  852772.0     10  2014            0             0
# 3   63220.0      3  2012            0             0
# 4     316.0      2  2009            0             0
#
# [5 rows x 23 columns]

# %%
for j in mov_train.index:
    x = mov_train.loc[j,"year"]
    y = inflation.loc[x-1900,'amount']
    mov_train.loc[j,'infl_budget'] = mov_train.loc[j,'budget']*35.48/y
    mov_train.loc[j,'infl_revenue'] = mov_train.loc[j,'revenue']*35.48/y
    
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#    ...                                           Keywords  \
# 0  ...  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  ...  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  ...  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  ...  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4  ...                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes  month  year   infl_budget  infl_revenue
# 0   39572.0      2  2015  1.760170e+07  1.548277e+07
# 1   82272.0      8  2004  6.310360e+07  1.501068e+08
# 2  852772.0     10  2014  4.154862e+06  1.648347e+07
# 3   63220.0      3  2012  1.557849e+06  2.077131e+07
# 4     316.0      2  2009  0.000000e+00  5.451153e+06
#
# [5 rows x 23 columns]

# %%
budget_zero.head()
# Out:
#     budget                                             genres    imdb_id  \
# 4        0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# 7        0                [{'id': 99, 'name': 'Documentary'}]  tt0391024
# 8        0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...  tt0117110
# 11       0                     [{'id': 35, 'name': 'Comedy'}]  tt0093857
# 17       0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...  tt1700845
#
#    original_language                              original_title  popularity  \
# 4                 ko                                        마린보이    1.148070
# 7                 en                                Control Room    1.949044
# 8                 en                      Muppet Treasure Island    6.902423
# 11                en  Revenge of the Nerds II: Nerds in Paradise   10.543750
# 17                en                         The Invisible Woman    4.183558
#
#                                  production_companies  \
# 4                                                 NaN
# 7                                                 NaN
# 8   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 11  [{'name': 'Twentieth Century Fox Film Corporat...
# 17  [{'name': 'BBC Films', 'id': 288}, {'name': 'H...
#
#                                  production_countries release_date  runtime  \
# 4       [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
# 7                                                 NaN      1/15/04     84.0
# 8   [{'iso_3166_1': 'US', 'name': 'United States o...      2/16/96    100.0
# 11  [{'iso_3166_1': 'US', 'name': 'United States o...      7/10/87     98.0
# 17   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     12/25/13    111.0
#
#                                      spoken_languages    status  \
# 4            [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 7   [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 8            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 17           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                          title  \
# 4                                   Marine Boy
# 7                                 Control Room
# 8                       Muppet Treasure Island
# 11  Revenge of the Nerds II: Nerds in Paradise
# 17                         The Invisible Woman
#
#                                              Keywords  \
# 4                                                 NaN
# 7   [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8   [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 11  [{'id': 5801, 'name': 'nerd'}, {'id': 6876, 'n...
# 17  [{'id': 5565, 'name': 'biography'}, {'id': 180...
#
#                                                  cast  \
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 7   [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8   [{'cast_id': 1, 'character': 'Long John Silver...
# 11  [{'cast_id': 2, 'character': 'Lewis Skolnick',...
# 17  [{'cast_id': 7, 'character': 'Charles Dickens'...
#
#                                                  crew   revenue  imdb_rating  \
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970          5.7
# 7   [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511          7.7
# 8   [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391          6.9
# 11  [{'credit_id': '52fe46f49251416c750891e9', 'de...  22642033          5.0
# 17  [{'credit_id': '53b94a260e0a2676c7009b37', 'de...   1234254          6.1
#
#     numVotes
# 4      316.0
# 7     5175.0
# 8    24612.0
# 11   14602.0
# 17   10048.0

# %%
mov_train['mod_budget'] = mov_train['infl_budget']
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#    ...                                               cast  \
# 0  ...  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  ...  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  ...  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  ...  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  ...  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes month  year   infl_budget  infl_revenue    mod_budget
# 0   39572.0     2  2015  1.760170e+07  1.548277e+07  1.760170e+07
# 1   82272.0     8  2004  6.310360e+07  1.501068e+08  6.310360e+07
# 2  852772.0    10  2014  4.154862e+06  1.648347e+07  4.154862e+06
# 3   63220.0     3  2012  1.557849e+06  2.077131e+07  1.557849e+06
# 4     316.0     2  2009  0.000000e+00  5.451153e+06  0.000000e+00
#
# [5 rows x 24 columns]

# %%
for j in budget_zero.index:
    x = budget_zero.loc[j,'year']
    this_genres=set()
    item = budget_zero.loc[j,'genres']
    if(type(item)==str):
        y=re.finditer("(\'name\':\s\')(?P<name>\w*)(?=\')",item)
        for s in y:
            this_genres.add(s.groupdict()['name'])
    total = 0
    total_2 = 0
    count = 0
    count_2 = 0
    for k in mov_train.index:
        if k not in budget_zero.index:
            if abs(mov_train.loc[k,'year'] - x)<= 3:
                total_2 = total_2 + mov_train.loc[k,'infl_budget']
                count_2 = count_2 + 1
                that_genres=set()
                item = mov_train.loc[k,'genres']
                if(type(item)==str):
                    y=re.finditer("(\'name\':\s\')(?P<name>\w*)(?=\')",item)
                    for s in y:
                        that_genres.add(s.groupdict()['name'])
                    if len(this_genres.intersection(that_genres))!= 0:
                        total = total + mov_train.loc[k,'infl_budget']
                        count = count + 1
    if count == 0:
        average = total_2/count_2
    else:
        average = total/count
    mov_train.loc[j,'mod_budget'] = average

# %%
mov_train.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 2                en                                  Whiplash   64.299990
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#    ...                                               cast  \
# 0  ...  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  ...  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  ...  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  ...  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  ...  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue imdb_rating  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         5.0
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         5.8
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         8.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         8.1
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         5.7
#
#    numVotes month  year   infl_budget  infl_revenue    mod_budget
# 0   39572.0     2  2015  1.760170e+07  1.548277e+07  1.760170e+07
# 1   82272.0     8  2004  6.310360e+07  1.501068e+08  6.310360e+07
# 2  852772.0    10  2014  4.154862e+06  1.648347e+07  4.154862e+06
# 3   63220.0     3  2012  1.557849e+06  2.077131e+07  1.557849e+06
# 4     316.0     2  2009  0.000000e+00  5.451153e+06  6.105908e+07
#
# [5 rows x 24 columns]

# %%
pd.plotting.scatter_matrix(mov_train[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021B9F09DAF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021B9F137FA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0A4E430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0A75880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0A9FCD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0AD30A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0AD3190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0AFC640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0B51E50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0B852E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0BB1760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0BDBBB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0C090A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0C41490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0C6D8E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0C9AD60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0CD2220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0A831F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0BED220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0D4E640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0D7BA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0DA9F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0DDF3D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA0E0B880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021BA2DE6CD0>]],
#       dtype=object)

# %%
corr_matrix1 = mov_train[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']].corr()

# %%
print(corr_matrix1)
# Out:
#               mod_budget  popularity   runtime  imdb_rating  infl_revenue
# mod_budget      1.000000    0.272392  0.260203     0.004243      0.594614
# popularity      0.272392    1.000000  0.133690     0.159394      0.383882
# runtime         0.260203    0.133690  1.000000     0.346248      0.254896
# imdb_rating     0.004243    0.159394  0.346248     1.000000      0.206060
# infl_revenue    0.594614    0.383882  0.254896     0.206060      1.000000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
mov_train_standard=mov_train.copy()
scaler=StandardScaler()
scaler.fit(mov_train_standard[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']])
mov_train_standard[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']]=scaler.transform(mov_train_standard[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']])

# %%
corr_matrix2 = mov_train_standard[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']].corr()

# %%
print(corr_matrix2)
# Out:
#               mod_budget  popularity   runtime  imdb_rating  infl_revenue
# mod_budget      1.000000    0.272392  0.260203     0.004243      0.594614
# popularity      0.272392    1.000000  0.133690     0.159394      0.383882
# runtime         0.260203    0.133690  1.000000     0.346248      0.254896
# imdb_rating     0.004243    0.159394  0.346248     1.000000      0.206060
# infl_revenue    0.594614    0.383882  0.254896     0.206060      1.000000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
mov_train_minmax=mov_train.copy()
scaler2=MinMaxScaler()
scaler2.fit(mov_train_minmax[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']])
mov_train_minmax[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']]=scaler2.transform(mov_train_minmax[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']])

# %%
corr_matrix3 = mov_train_minmax[['mod_budget','popularity','runtime','imdb_rating','infl_revenue']].corr()
print(corr_matrix3)
# Out:
#               mod_budget  popularity   runtime  imdb_rating  infl_revenue
# mod_budget      1.000000    0.272392  0.260203     0.004243      0.594614
# popularity      0.272392    1.000000  0.133690     0.159394      0.383882
# runtime         0.260203    0.133690  1.000000     0.346248      0.254896
# imdb_rating     0.004243    0.159394  0.346248     1.000000      0.206060
# infl_revenue    0.594614    0.383882  0.254896     0.206060      1.000000
